# %%
import matplotlib.pyplot as plt 
import numpy as np
x=np.linspace(0,10,10)# starting point,ending point and no.of points in between

# %%
y=np.sin(x)

# %%
plt.plot(x,y) #to plot

# %%
plt.show() #to show

# %%
plt.plot(x,y)

# %%
plt.xlabel("time")

# %%
plt.ylabel("f(t)")

# %%
plt.title("my cool chart")

# %%
plt.show() #to show

# %%
x=np.linspace(1,10,100)# starting point,ending point and no.of points in between
y=np.sin(x)
plt.plot(x,y) #to plot
plt.show() #to show

# %%
m=np.exp(x)

plt.scatter(x,m)

# %%
plt.show()

# %%
a=np.linspace(0,100,100)
b=2*a+1

# %%
plt.scatter(a,b)

# %%
x=np.linspace(1,100,100)# starting point,ending point and no.of points in between

plt.plot(x,y)

# %%
plt.show()

# %%
plt.hist(y)  #histogram
# Out:
# (array([ 14.,   7.,   6.,   8.,   7.,   6.,   6.,   9.,   9.,  28.]),
#  array([ -9.99889239e-01,  -7.99932424e-01,  -5.99975608e-01,
#          -4.00018793e-01,  -2.00061978e-01,  -1.05162420e-04,
#           1.99851653e-01,   3.99808468e-01,   5.99765284e-01,
#           7.99722099e-01,   9.99678914e-01]),
#  <a list of 10 Patch objects>)

# %%
plt.show()

# %%
R= np.random.random(1000)
plt.hist(R)
# Out:
# (array([  92.,  103.,  104.,   98.,  115.,  101.,   84.,   93.,  104.,  106.]),
#  array([ 0.00184812,  0.10165436,  0.2014606 ,  0.30126684,  0.40107309,
#          0.50087933,  0.60068557,  0.70049181,  0.80029805,  0.9001043 ,
#          0.99991054]),
#  <a list of 10 Patch objects>)

# %%
plt.show()

# %%
plt.hist(R,bins=20)#no of bins increased from 10 to 20
# Out:
# (array([ 45.,  47.,  47.,  56.,  54.,  50.,  46.,  52.,  60.,  55.,  53.,
#          48.,  46.,  38.,  43.,  50.,  50.,  54.,  51.,  55.]),
#  array([ 0.00184812,  0.05175124,  0.10165436,  0.15155748,  0.2014606 ,
#          0.25136372,  0.30126684,  0.35116997,  0.40107309,  0.45097621,
#          0.50087933,  0.55078245,  0.60068557,  0.65058869,  0.70049181,
#          0.75039493,  0.80029805,  0.85020117,  0.9001043 ,  0.95000742,
#          0.99991054]),
#  <a list of 20 Patch objects>)

# %%
    plt.show()
